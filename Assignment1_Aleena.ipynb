# %% [markdown]
# **ASSIGNMENT 1**
#
# Submitted By:Aleena Anna Plessey 21BCE5767 VIT Chennai
#
# TRACK:Artificial Intelligence & Machine Learning in collaboration with Google
# (Applied Data Science)

# %%
import pandas as pd
from numpy import nan

# %% [markdown]
# **Task - 1 Create a pandas dataframe (DataFrame name as 'df') (10 observation and 5 features)**

# %%
d={'id':[11,22,33,44,55,66,77,88,99,10],
    'Name':['Andy','Dave','Ayesha','Abel','Devi','Joe','Shruthi','Sumi','Avni',
            'Rohan'],
    'Grade':['A',nan,'S','D','F','B','A','D','D',nan],
    'City':['Kochi','Delhi','Kochi','Mumbai','Pune',nan,'Delhi','Delhi','Pune',
            'Kolkata'],
    'Major':['Maths','Biology','English','Biology','English','English','Math',
             nan,'English',nan]}

# %%
df=pd.DataFrame(d)
df
# Out:
#    id     Name Grade     City    Major
# 0  11     Andy     A    Kochi    Maths
# 1  22     Dave   NaN    Delhi  Biology
# 2  33   Ayesha     S    Kochi  English
# 3  44     Abel     D   Mumbai  Biology
# 4  55     Devi     F     Pune  English
# 5  66      Joe     B      NaN  English
# 6  77  Shruthi     A    Delhi     Math
# 7  88     Sumi     D    Delhi      NaN
# 8  99     Avni     D     Pune  English
# 9  10    Rohan   NaN  Kolkata      NaN

# %% [markdown]
# **Task- 2 Check the info of 'df'**

# %%
df.info() #checking the info of df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      10 non-null     int64
#  1   Name    10 non-null     object
#  2   Grade   8 non-null      object
#  3   City    9 non-null      object
#  4   Major   8 non-null      object
# dtypes: int64(1), object(4)
# memory usage: 528.0+ bytes

# %% [markdown]
# **Task 3- Check the descriptive statistics of 'df'**

# %%
df.describe() #checking the descriptive statistics of df
# Out:
#               id
# count  10.000000
# mean   50.500000
# std    31.767384
# min    10.000000
# 25%    24.750000
# 50%    49.500000
# 75%    74.250000
# max    99.000000

# %% [markdown]
# **Task 4- check the 4th index observation with 'loc' slicing operator.**

# %%
df.loc[4] #checking the fourth index observation with loc slicing operator
# Out:
# id            55
# Name        Devi
# Grade          F
# City        Pune
# Major    English
# Name: 4, dtype: object

# %% [markdown]
# **Task 5 - Check the null values in your 'df'**

# %%
df.isnull().any() #checking for null values
# Out:
# id       False
# Name     False
# Grade     True
# City      True
# Major     True
# dtype: bool

# %%
df.isnull() #checking the null values
# Out:
#       id   Name  Grade   City  Major
# 0  False  False  False  False  False
# 1  False  False   True  False  False
# 2  False  False  False  False  False
# 3  False  False  False  False  False
# 4  False  False  False  False  False
# 5  False  False  False   True  False
# 6  False  False  False  False  False
# 7  False  False  False  False   True
# 8  False  False  False  False  False
# 9  False  False   True  False   True
